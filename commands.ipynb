# %%
# !python test.py
# Out:
# /Users/nanakdeepsingh/Projects/Code/JIRA_PII/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/nanakdeepsingh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nanakdeepsingh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/nanakdeepsingh/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ...

# %%
# Out:
# [{'id': '10003', 'piiLeak': False},
#  {'id': '10002',
#   'piiLeak': True,
#   'attachments': [{'filename': 'Screenshot 2024-02-05 at 3.11.19\u202fPM.png',
#     'PII_leak': True,
#     'Leaks': [{'entity_group': 'MIDDLENAME',
#       'score': 0.7750023,
#       'word': ' john',
#       'start': 73,
#       'end': 78},
#      {'entity_group': 'MIDDLENAME',
#       'score': 0.89686626,
#       'word': ' doe',
#       'start': 78,
#       'end': 82},
#      {'entity_group': 'STREETADDRESS',
#       'score': 0.9057288,
#       'word': ' 1234 elm street springfield',
#       'start': 97,
#       'end': 125},
#      {'entity_group': 'BUILDINGNUMBER',
#       'score': 0.6159391,
#       'word': ' 12345',
#       'start': 134,
#       'end': 140},
#      {'entity_group': 'PIN',
#       'score': 0.5280352,
#       'word': ' 555',
#       'start': 179,
#       'end': 183},
#      {'entity_group': 'PHONE_NUMBER',
#       'score': 0.3064707,
#       'word': ' 123 4567',
#       'start': 183,
# ...
