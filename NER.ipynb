# %%
text="mask all personally identificable information PII including person names for the text below: John Doe, currently lives at 1234 Elm Street, Springfield, Anywhere 12345.  He can be reached at johndoe@email.com or at the phone number 555-123-4567. His social security number is 123-45-6789, and he has a bank account number 9876543210 at Springfield Bank. John attended Springfield University where he earned  a Bachelor's degree in Computer Science. He now works at Acme Corp and his employee ID is 123456. John's medical record number is MRN-001234, and he has a history of asthma and high blood pressure. His primary care physician is Dr. Jane Smith,  who practices at Springfield Medical Center. His recent blood test results show a cholesterol level of 200 mg/dL and a  blood glucose level of 90 mg/dL."

# %%
# !git lfs install
# !git clone https://huggingface.co/lakshyakh93/deberta_finetuned_pii
# Out:
# Git LFS initialized.
# Cloning into 'deberta_finetuned_pii'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 34 (delta 9), reused 0 (delta 0), pack-reused 4
# Unpacking objects: 100% (34/34), 1.09 MiB | 1.70 MiB/s, done.
# Filtering content: 100% (5/5), 1.55 GiB | 10.94 MiB/s, done.

# %%
# import spacy
# nlp = spacy.load("en_spacy_pii_distilbert")

# %%
# def show_ents(doc):
#     if doc.ents: 
#         for ent in doc.ents:
#             print(ent.text+'- ' +str(ent.start_char) +' - '+ str(ent.end_char) +'-'+ent.label_ + ' - '+str(spacy.explain(ent.label_)))
#     else:
#         print('No named entities found.')

# %%
# docs=nlp(text)
# show_ents(docs)

# %%
from transformers import pipeline
gen = pipeline("token-classification", "lakshyakh93/deberta_finetuned_pii", device=-1)

# %%
# # Load model directly
# from transformers import AutoTokenizer, AutoModelForTokenClassification

# tokenizer = AutoTokenizer.from_pretrained("lakshyakh93/deberta_finetuned_pii")
# model = AutoModelForTokenClassification.from_pretrained("lakshyakh93/deberta_finetuned_pii")

# %%
output = gen(text, aggregation_strategy="first")
print(output)
# Out:
# [{'entity_group': 'FIRSTNAME', 'score': 0.4722297, 'word': ' John', 'start': 92, 'end': 97}, {'entity_group': 'STREETADDRESS', 'score': 0.9894896, 'word': ' 1234 Elm Street,', 'start': 121, 'end': 138}, {'entity_group': 'CITY', 'score': 0.7245631, 'word': ' Springfield,', 'start': 138, 'end': 151}, {'entity_group': 'ZIPCODE', 'score': 0.9853234, 'word': ' 12345.', 'start': 160, 'end': 167}, {'entity_group': 'EMAIL', 'score': 0.9995962, 'word': ' johndoe@email.com', 'start': 189, 'end': 207}, {'entity_group': 'PHONE_NUMBER', 'score': 0.99415284, 'word': ' 555-123-4567.', 'start': 230, 'end': 244}, {'entity_group': 'SSN', 'score': 0.9933657, 'word': ' 123-45-6789,', 'start': 274, 'end': 287}, {'entity_group': 'ACCOUNTNUMBER', 'score': 0.99866366, 'word': ' 9876543210', 'start': 320, 'end': 331}, {'entity_group': 'FIRSTNAME', 'score': 0.42572698, 'word': ' John', 'start': 352, 'end': 357}, {'entity_group': 'COMPANY_NAME', 'score': 0.97809064, 'word': ' Acme Corp', 'start': 463, 'end': 4
# ...

# %%
[{'entity_group': 'FIRSTNAME', 'score': 0.4722297, 'word': ' John', 'start': 92, 'end': 97}, {'entity_group': 'STREETADDRESS', 'score': 0.9894896, 'word': ' 1234 Elm Street,', 'start': 121, 'end': 138}, {'entity_group': 'CITY', 'score': 0.7245631, 'word': ' Springfield,', 'start': 138, 'end': 151}, {'entity_group': 'ZIPCODE', 'score': 0.9853234, 'word': ' 12345.', 'start': 160, 'end': 167}, {'entity_group': 'EMAIL', 'score': 0.9995962, 'word': ' johndoe@email.com', 'start': 189, 'end': 207}, {'entity_group': 'PHONE_NUMBER', 'score': 0.99415284, 'word': ' 555-123-4567.', 'start': 230, 'end': 244}, {'entity_group': 'SSN', 'score': 0.9933657, 'word': ' 123-45-6789,', 'start': 274, 'end': 287}, {'entity_group': 'ACCOUNTNUMBER', 'score': 0.99866366, 'word': ' 9876543210', 'start': 320, 'end': 331}, {'entity_group': 'FIRSTNAME', 'score': 0.42572698, 'word': ' John', 'start': 352, 'end': 357}, {'entity_group': 'COMPANY_NAME', 'score': 0.97809064, 'word': ' Acme Corp', 'start': 463, 'end': 473}, {'entity_group': 'PIN', 'score': 0.92833185, 'word': ' 123456.', 'start': 496, 'end': 504}, {'entity_group': 'FIRSTNAME', 'score': 0.62752926, 'word': " John's", 'start': 504, 'end': 511}, {'entity_group': 'VEHICLEVRM', 'score': 0.932783, 'word': ' MRN-001234,', 'start': 536, 'end': 548}, {'entity_group': 'MIDDLENAME', 'score': 0.8049485, 'word': ' Jane', 'start': 638, 'end': 643}, {'entity_group': 'LASTNAME', 'score': 0.50753546, 'word': ' Smith,', 'start': 643, 'end': 650}, {'entity_group': 'AMOUNT', 'score': 0.3982958, 'word': ' 90', 'start': 794, 'end': 797}]
# Out:
# [{'entity_group': 'FIRSTNAME',
#   'score': 0.4722297,
#   'word': ' John',
#   'start': 92,
#   'end': 97},
#  {'entity_group': 'STREETADDRESS',
#   'score': 0.9894896,
#   'word': ' 1234 Elm Street,',
#   'start': 121,
#   'end': 138},
#  {'entity_group': 'CITY',
#   'score': 0.7245631,
#   'word': ' Springfield,',
#   'start': 138,
#   'end': 151},
#  {'entity_group': 'ZIPCODE',
#   'score': 0.9853234,
#   'word': ' 12345.',
#   'start': 160,
#   'end': 167},
#  {'entity_group': 'EMAIL',
#   'score': 0.9995962,
#   'word': ' johndoe@email.com',
#   'start': 189,
#   'end': 207},
#  {'entity_group': 'PHONE_NUMBER',
#   'score': 0.99415284,
#   'word': ' 555-123-4567.',
#   'start': 230,
#   'end': 244},
#  {'entity_group': 'SSN',
#   'score': 0.9933657,
#   'word': ' 123-45-6789,',
#   'start': 274,
#   'end': 287},
#  {'entity_group': 'ACCOUNTNUMBER',
#   'score': 0.99866366,
#   'word': ' 9876543210',
#   'start': 320,
#   'end': 331},
#  {'entity_group': 'FIRSTNAME',
# ...

# %%
# This code sample uses the 'requests' library:
# http://docs.python-requests.org
import requests
from requests.auth import HTTPBasicAuth
import json

url = "https://ndsingh.atlassian.net/rest/api/2/search?jql=project=KAN&maxResults=1000"

auth = HTTPBasicAuth("nanakdeep37@gmail.com", "ATATT3xFfGF02nXCViEDY9VhflTc8llK2nyayBSqPLdHm7n9kF0PRsjO8YspGnyFUYmmQ7wUe2g84Zg7MacduiaFycABqESyT0XhDKxiL465UJl8pFZe_rLNVSCQgJa7HJAmDMbZhvjLOlgWwXA8_BmpWXT-aBH7KN7MgPMkJP7ozycbr7aFMzE=E40165D6")

headers = {
  "Accept": "application/json"
}

response = requests.request(
   "GET",
   url,
   headers=headers,
   auth=auth
)

out=json.loads(response.text)

# %%
"ATATT3xFfGF02nXCViEDY9VhflTc8llK2nyayBSqPLdHm7n9kF0PRsjO8YspGnyFUYmmQ7wUe2g84Zg7MacduiaFycABqESyT0XhDKxiL465UJl8pFZe_rLNVSCQgJa7HJAmDMbZhvjLOlgWwXA8_BmpWXT-aBH7KN7MgPMkJP7ozycbr7aFMzE=E40165D6"
# Out:
# 'ATATT3xFfGF02nXCViEDY9VhflTc8llK2nyayBSqPLdHm7n9kF0PRsjO8YspGnyFUYmmQ7wUe2g84Zg7MacduiaFycABqESyT0XhDKxiL465UJl8pFZe_rLNVSCQgJa7HJAmDMbZhvjLOlgWwXA8_BmpWXT-aBH7KN7MgPMkJP7ozycbr7aFMzE=E40165D6'

# %%
out
# Out:
# {'expand': 'schema,names',
#  'startAt': 0,
#  'maxResults': 100,
#  'total': 4,
#  'issues': [{'expand': 'operations,versionedRepresentations,editmeta,changelog,customfield_10010.requestTypePractice,renderedFields',
#    'id': '10003',
#    'self': 'https://ndsingh.atlassian.net/rest/api/2/issue/10003',
#    'key': 'KAN-4',
#    'fields': {'statuscategorychangedate': '2024-02-01T17:10:48.311+0530',
#     'issuetype': {'self': 'https://ndsingh.atlassian.net/rest/api/2/issuetype/10001',
#      'id': '10001',
#      'description': 'A small, distinct piece of work.',
#      'iconUrl': 'https://ndsingh.atlassian.net/rest/api/2/universal_avatar/view/type/issuetype/avatar/10318?size=medium',
#      'name': 'Task',
#      'subtask': False,
#      'avatarId': 10318,
#      'entityId': '2b85f1bd-d03d-46de-93e7-02fadb099ade',
#      'hierarchyLevel': 0},
#     'timespent': None,
#     'project': {'self': 'https://ndsingh.atlassian.net/rest/api/2/project/10000',
#      'id': '10000',
# ...

# %%
issues=out["issues"]
print(len(issues))
issues
# Out:
# 5
# [{'expand': 'operations,versionedRepresentations,editmeta,changelog,customfield_10010.requestTypePractice,renderedFields',
#   'id': '10004',
#   'self': 'https://ndsingh.atlassian.net/rest/api/2/issue/10004',
#   'key': 'KAN-5',
#   'fields': {'statuscategorychangedate': '2024-02-02T12:35:47.799+0530',
#    'issuetype': {'self': 'https://ndsingh.atlassian.net/rest/api/2/issuetype/10001',
#     'id': '10001',
#     'description': 'A small, distinct piece of work.',
#     'iconUrl': 'https://ndsingh.atlassian.net/rest/api/2/universal_avatar/view/type/issuetype/avatar/10318?size=medium',
#     'name': 'Task',
#     'subtask': False,
#     'avatarId': 10318,
#     'entityId': '2b85f1bd-d03d-46de-93e7-02fadb099ade',
#     'hierarchyLevel': 0},
#    'timespent': None,
#    'project': {'self': 'https://ndsingh.atlassian.net/rest/api/2/project/10000',
#     'id': '10000',
#     'key': 'KAN',
#     'name': 'My Kanban Project',
#     'projectTypeKey': 'software',
# ...

# %%
for i in issues:
    text=i["fields"]["summary"]
    print(text)
    print(gen(text, aggregation_strategy="first"))
# Out:
# abc
# [{'entity_group': 'FIRSTNAME', 'score': 0.99326223, 'word': ' abc', 'start': 0, 'end': 3}]
# work on the app
# []
# Nothing at the moment
# []
# John Doe, currently lives at 1234 Elm Street, Springfield, Anywhere 12345. He can be reached at johndoe@email.com or at the phone number 555-123-4567. His social security number is 123-45-678 He now works at Acme Corp and his employee ID is 123456.
# ...

# %%
for i in issues:
    text=i["fields"]["summary"]
    out=gen(text, aggregation_strategy="first")
    if len(out):
        print(i["id"],"info leaked")
        print(out)
    else:
        print(i["id"],"no issues")
# Out:
# 10004 info leaked
# [{'entity_group': 'FIRSTNAME', 'score': 0.99326223, 'word': ' abc', 'start': 0, 'end': 3}]
# 10003 no issues
# 10002 no issues
# 10001 info leaked
# ...

# %%
# uploading image
# fast api

# %%
#Vishal sagar aditya and hemant

# %%
# # # Load model directly
from transformers import AutoTokenizer, AutoModelForTokenClassification
model_path="./deberta_finetuned_pii"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForTokenClassification.from_pretrained(model_path)
gen = pipeline("token-classification",model=model,tokenizer=tokenizer, device=-1)

output = gen(text, aggregation_strategy="first")
output
# Out:
# [{'entity_group': 'FIRSTNAME',
#   'score': 0.4722297,
#   'word': ' John',
#   'start': 92,
#   'end': 97},
#  {'entity_group': 'STREETADDRESS',
#   'score': 0.9894896,
#   'word': ' 1234 Elm Street,',
#   'start': 121,
#   'end': 138},
#  {'entity_group': 'CITY',
#   'score': 0.7245631,
#   'word': ' Springfield,',
#   'start': 138,
#   'end': 151},
#  {'entity_group': 'ZIPCODE',
#   'score': 0.9853234,
#   'word': ' 12345.',
#   'start': 160,
#   'end': 167},
#  {'entity_group': 'EMAIL',
#   'score': 0.9995962,
#   'word': ' johndoe@email.com',
#   'start': 189,
#   'end': 207},
#  {'entity_group': 'PHONE_NUMBER',
#   'score': 0.99415284,
#   'word': ' 555-123-4567.',
#   'start': 230,
#   'end': 244},
#  {'entity_group': 'SSN',
#   'score': 0.9933657,
#   'word': ' 123-45-6789,',
#   'start': 274,
#   'end': 287},
#  {'entity_group': 'ACCOUNTNUMBER',
#   'score': 0.99866366,
#   'word': ' 9876543210',
#   'start': 320,
#   'end': 331},
#  {'entity_group': 'FIRSTNAME',
# ...

# %%
# Out:
# [{'entity_group': 'FIRSTNAME',
#   'score': 0.4722297,
#   'word': ' John',
#   'start': 92,
#   'end': 97},
#  {'entity_group': 'STREETADDRESS',
#   'score': 0.9894896,
#   'word': ' 1234 Elm Street,',
#   'start': 121,
#   'end': 138},
#  {'entity_group': 'CITY',
#   'score': 0.7245631,
#   'word': ' Springfield,',
#   'start': 138,
#   'end': 151},
#  {'entity_group': 'ZIPCODE',
#   'score': 0.9853234,
#   'word': ' 12345.',
#   'start': 160,
#   'end': 167},
#  {'entity_group': 'EMAIL',
#   'score': 0.9995962,
#   'word': ' johndoe@email.com',
#   'start': 189,
#   'end': 207},
#  {'entity_group': 'PHONE_NUMBER',
#   'score': 0.99415284,
#   'word': ' 555-123-4567.',
#   'start': 230,
#   'end': 244},
#  {'entity_group': 'SSN',
#   'score': 0.9933657,
#   'word': ' 123-45-6789,',
#   'start': 274,
#   'end': 287},
#  {'entity_group': 'ACCOUNTNUMBER',
#   'score': 0.99866366,
#   'word': ' 9876543210',
#   'start': 320,
#   'end': 331},
#  {'entity_group': 'FIRSTNAME',
# ...

# %%
from utils.io import FileProcessor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from utils.io import FileProcessor
#
# File ~/Projects/Code/JIRA_PII/utils/io.py:14
#      12 from utils.constants import FileEntry, FileType, PredictionTypes
#      13 from utils.encryption import calculate_sha256
# ---> 14 from utils.ocr import get_docx_text, get_excel_text, get_image_text, get_pdf_text
#      17 class FileProcessor:
#      18     def __init__(self, documents: list, request_id: str, segregate: bool = False):
#
# File ~/Projects/Code/JIRA_PII/utils/ocr.py:15
#      13 from nltk.corpus import stopwords
#      14 from nltk.stem import WordNetLemmatizer
# ---> 15 from paddleocr import PaddleOCR
#      16 from PIL import Image
#      18 # HACK
#      19 # os.environ["KMP_DUPLICATE_LIB_OK"] = "True"
#
# ...

# %%
# !python -m pip install paddlepaddle -i https://pypi.tuna.tsinghua.edu.cn/simple
# !pip install "paddleocr>=2.0.1" # Recommend to use version 2.0.1+
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 MB 190.1 kB/s eta 0:00:0000:0100:09
# ...

# %%
import requests
from requests.auth import HTTPBasicAuth
import json
import os

# token = os.environ['jiraToken']
# adminId= os.environ['adminId']
token="ATATT3xFfGF02nXCViEDY9VhflTc8llK2nyayBSqPLdHm7n9kF0PRsjO8YspGnyFUYmmQ7wUe2g84Zg7MacduiaFycABqESyT0XhDKxiL465UJl8pFZe_rLNVSCQgJa7HJAmDMbZhvjLOlgWwXA8_BmpWXT-aBH7KN7MgPMkJP7ozycbr7aFMzE=E40165D6"
adminId="nanakdeep37@gmail.com"
base_url='https://ndsingh.atlassian.net'

def get_issues(project_key:str):
    url = f"{base_url}/rest/api/2/search?jql=project={project_key}&fields=id&maxResults=100"

    auth = HTTPBasicAuth(adminId, token)

    headers = {
    "Accept": "application/json"
    }

    response = requests.request(
    "GET",
    url,
    headers=headers,
    auth=auth
    )
    out=json.loads(response.text)
    # issues=out["issues"]
    return out

# %%
get_issues("KAN")
# Out:
# {'expand': 'schema,names',
#  'startAt': 0,
#  'maxResults': 100,
#  'total': 4,
#  'issues': [{'expand': 'operations,versionedRepresentations,editmeta,changelog,renderedFields',
#    'id': '10003',
#    'self': 'https://ndsingh.atlassian.net/rest/api/2/issue/10003',
#    'key': 'KAN-4'},
#   {'expand': 'operations,versionedRepresentations,editmeta,changelog,renderedFields',
#    'id': '10002',
#    'self': 'https://ndsingh.atlassian.net/rest/api/2/issue/10002',
#    'key': 'KAN-3'},
#   {'expand': 'operations,versionedRepresentations,editmeta,changelog,renderedFields',
#    'id': '10001',
#    'self': 'https://ndsingh.atlassian.net/rest/api/2/issue/10001',
#    'key': 'KAN-2'},
#   {'expand': 'operations,versionedRepresentations,editmeta,changelog,renderedFields',
#    'id': '10000',
#    'self': 'https://ndsingh.atlassian.net/rest/api/2/issue/10000',
#    'key': 'KAN-1'}]}

# %%
import requests
from requests.auth import HTTPBasicAuth
import json
import os

# token = os.environ['jiraToken']
# adminId= os.environ['adminId']
token="ATATT3xFfGF02nXCViEDY9VhflTc8llK2nyayBSqPLdHm7n9kF0PRsjO8YspGnyFUYmmQ7wUe2g84Zg7MacduiaFycABqESyT0XhDKxiL465UJl8pFZe_rLNVSCQgJa7HJAmDMbZhvjLOlgWwXA8_BmpWXT-aBH7KN7MgPMkJP7ozycbr7aFMzE=E40165D6"
adminId="nanakdeep37@gmail.com"
base_url='https://ndsingh.atlassian.net'

def get_issues(project_key:str):
    url = f"{base_url}/rest/api/2/search?jql=project={project_key}&fields=id&maxResults=100"

    auth = HTTPBasicAuth(adminId, token)

    headers = {
    "Accept": "application/json"
    }

    response = requests.request(
    "GET",
    url,
    headers=headers,
    auth=auth
    )
    out=json.loads(response.text)
    issueIds=out["issues"]
    issues_data=[]
    for issue in issueIds:
        issues_data.append(fetch_issue(issue['id']))
    return issues_data
#ideally we should fetch these datapoints at once by jql


def fetch_issue(id):
    
    url = f"{base_url}/rest/api/3/issue/{id}"
    auth = HTTPBasicAuth(adminId,token)

    headers = {
    "Accept": "application/json"
    }

    res = requests.request(
    "GET",
    url,
    headers=headers,
    auth=auth
    )

    return json.loads(res.text)

# %%
issues=get_issues("KAN")
print(issues)
# Out:
# [{'expand': 'renderedFields,names,schema,operations,editmeta,changelog,versionedRepresentations,customfield_10010.requestTypePractice', 'id': '10003', 'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/10003', 'key': 'KAN-4', 'fields': {'statuscategorychangedate': '2024-02-01T17:10:48.311+0530', 'issuetype': {'self': 'https://ndsingh.atlassian.net/rest/api/3/issuetype/10001', 'id': '10001', 'description': 'A small, distinct piece of work.', 'iconUrl': 'https://ndsingh.atlassian.net/rest/api/2/universal_avatar/view/type/issuetype/avatar/10318?size=medium', 'name': 'Task', 'subtask': False, 'avatarId': 10318, 'entityId': '2b85f1bd-d03d-46de-93e7-02fadb099ade', 'hierarchyLevel': 0}, 'timespent': None, 'customfield_10031': None, 'project': {'self': 'https://ndsingh.atlassian.net/rest/api/3/project/10000', 'id': '10000', 'key': 'KAN', 'name': 'My Kanban Project', 'projectTypeKey': 'software', 'simplified': True, 'avatarUrls': {'48x48': 'https://ndsingh.atlassian.net/rest/api/3/univer
# ...

# %%
[{'expand': 'renderedFields,names,schema,operations,editmeta,changelog,versionedRepresentations,customfield_10010.requestTypePractice', 'id': '10003', 'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/10003', 'key': 'KAN-4', 'fields': {'statuscategorychangedate': '2024-02-01T17:10:48.311+0530', 'issuetype': {'self': 'https://ndsingh.atlassian.net/rest/api/3/issuetype/10001', 'id': '10001', 'description': 'A small, distinct piece of work.', 'iconUrl': 'https://ndsingh.atlassian.net/rest/api/2/universal_avatar/view/type/issuetype/avatar/10318?size=medium', 'name': 'Task', 'subtask': False, 'avatarId': 10318, 'entityId': '2b85f1bd-d03d-46de-93e7-02fadb099ade', 'hierarchyLevel': 0}, 'timespent': None, 'customfield_10031': None, 'project': {'self': 'https://ndsingh.atlassian.net/rest/api/3/project/10000', 'id': '10000', 'key': 'KAN', 'name': 'My Kanban Project', 'projectTypeKey': 'software', 'simplified': True, 'avatarUrls': {'48x48': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412', '24x24': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412?size=small', '16x16': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412?size=xsmall', '32x32': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412?size=medium'}}, 'customfield_10032': None, 'fixVersions': [], 'aggregatetimespent': None, 'resolution': None, 'customfield_10027': None, 'customfield_10028': None, 'customfield_10029': None, 'resolutiondate': None, 'workratio': -1, 'issuerestriction': {'issuerestrictions': {}, 'shouldDisplay': True}, 'lastViewed': None, 'watches': {'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/KAN-4/watchers', 'watchCount': 1, 'isWatching': True}, 'created': '2024-02-01T17:10:48.075+0530', 'customfield_10020': None, 'customfield_10021': None, 'customfield_10022': None, 'priority': {'self': 'https://ndsingh.atlassian.net/rest/api/3/priority/3', 'iconUrl': 'https://ndsingh.atlassian.net/images/icons/priorities/medium.svg', 'name': 'Medium', 'id': '3'}, 'customfield_10023': None, 'customfield_10024': None, 'customfield_10025': None, 'customfield_10026': None, 'labels': [], 'customfield_10016': None, 'customfield_10017': None, 'customfield_10018': {'hasEpicLinkFieldDependency': False, 'showField': False, 'nonEditableReason': {'reason': 'PLUGIN_LICENSE_ERROR', 'message': 'The Parent Link is only available to Jira Premium users.'}}, 'customfield_10019': '0|i0000n:', 'timeestimate': None, 'aggregatetimeoriginalestimate': None, 'versions': [], 'issuelinks': [], 'assignee': None, 'updated': '2024-02-01T17:10:48.118+0530', 'status': {'self': 'https://ndsingh.atlassian.net/rest/api/3/status/10000', 'description': '', 'iconUrl': 'https://ndsingh.atlassian.net/', 'name': 'To Do', 'id': '10000', 'statusCategory': {'self': 'https://ndsingh.atlassian.net/rest/api/3/statuscategory/2', 'id': 2, 'key': 'new', 'colorName': 'blue-gray', 'name': 'To Do'}}, 'components': [], 'timeoriginalestimate': None, 'description': None, 'customfield_10010': None, 'customfield_10014': None, 'customfield_10015': None, 'timetracking': {}, 'customfield_10005': None, 'customfield_10006': None, 'customfield_10007': None, 'security': None, 'customfield_10008': None, 'attachment': [], 'aggregatetimeestimate': None, 'customfield_10009': None, 'summary': 'work on the app', 'creator': {'self': 'https://ndsingh.atlassian.net/rest/api/3/user?accountId=712020%3Ab7569eea-9d96-46ba-8f8a-7a3a84d14125', 'accountId': '712020:b7569eea-9d96-46ba-8f8a-7a3a84d14125', 'emailAddress': 'nanakdeep37@gmail.com', 'avatarUrls': {'48x48': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '24x24': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '16x16': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '32x32': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png'}, 'displayName': 'Nanakdeep Singh Sidhu', 'active': True, 'timeZone': 'Asia/Calcutta', 'accountType': 'atlassian'}, 'subtasks': [], 'reporter': {'self': 'https://ndsingh.atlassian.net/rest/api/3/user?accountId=712020%3Ab7569eea-9d96-46ba-8f8a-7a3a84d14125', 'accountId': '712020:b7569eea-9d96-46ba-8f8a-7a3a84d14125', 'emailAddress': 'nanakdeep37@gmail.com', 'avatarUrls': {'48x48': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '24x24': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '16x16': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '32x32': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png'}, 'displayName': 'Nanakdeep Singh Sidhu', 'active': True, 'timeZone': 'Asia/Calcutta', 'accountType': 'atlassian'}, 'aggregateprogress': {'progress': 0, 'total': 0}, 'customfield_10001': None, 'customfield_10002': None, 'customfield_10003': None, 'customfield_10004': None, 'environment': None, 'duedate': None, 'progress': {'progress': 0, 'total': 0}, 'comment': {'comments': [], 'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/10003/comment', 'maxResults': 0, 'total': 0, 'startAt': 0}, 'votes': {'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/KAN-4/votes', 'votes': 0, 'hasVoted': False}, 'worklog': {'startAt': 0, 'maxResults': 20, 'total': 0, 'worklogs': []}}}, {'expand': 'renderedFields,names,schema,operations,editmeta,changelog,versionedRepresentations,customfield_10010.requestTypePractice', 'id': '10002', 'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/10002', 'key': 'KAN-3', 'fields': {'statuscategorychangedate': '2024-02-01T17:10:38.994+0530', 'issuetype': {'self': 'https://ndsingh.atlassian.net/rest/api/3/issuetype/10001', 'id': '10001', 'description': 'A small, distinct piece of work.', 'iconUrl': 'https://ndsingh.atlassian.net/rest/api/2/universal_avatar/view/type/issuetype/avatar/10318?size=medium', 'name': 'Task', 'subtask': False, 'avatarId': 10318, 'entityId': '2b85f1bd-d03d-46de-93e7-02fadb099ade', 'hierarchyLevel': 0}, 'timespent': None, 'customfield_10031': None, 'project': {'self': 'https://ndsingh.atlassian.net/rest/api/3/project/10000', 'id': '10000', 'key': 'KAN', 'name': 'My Kanban Project', 'projectTypeKey': 'software', 'simplified': True, 'avatarUrls': {'48x48': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412', '24x24': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412?size=small', '16x16': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412?size=xsmall', '32x32': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412?size=medium'}}, 'customfield_10032': None, 'fixVersions': [], 'aggregatetimespent': None, 'resolution': None, 'customfield_10027': None, 'customfield_10028': None, 'customfield_10029': None, 'resolutiondate': None, 'workratio': -1, 'watches': {'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/KAN-3/watchers', 'watchCount': 1, 'isWatching': True}, 'issuerestriction': {'issuerestrictions': {}, 'shouldDisplay': True}, 'lastViewed': None, 'created': '2024-02-01T17:10:38.619+0530', 'customfield_10020': None, 'customfield_10021': None, 'customfield_10022': None, 'customfield_10023': None, 'priority': {'self': 'https://ndsingh.atlassian.net/rest/api/3/priority/3', 'iconUrl': 'https://ndsingh.atlassian.net/images/icons/priorities/medium.svg', 'name': 'Medium', 'id': '3'}, 'customfield_10024': None, 'customfield_10025': None, 'labels': [], 'customfield_10026': None, 'customfield_10016': None, 'customfield_10017': None, 'customfield_10018': {'hasEpicLinkFieldDependency': False, 'showField': False, 'nonEditableReason': {'reason': 'PLUGIN_LICENSE_ERROR', 'message': 'The Parent Link is only available to Jira Premium users.'}}, 'customfield_10019': '0|i0000f:', 'timeestimate': None, 'aggregatetimeoriginalestimate': None, 'versions': [], 'issuelinks': [], 'assignee': None, 'updated': '2024-02-01T17:10:38.719+0530', 'status': {'self': 'https://ndsingh.atlassian.net/rest/api/3/status/10000', 'description': '', 'iconUrl': 'https://ndsingh.atlassian.net/', 'name': 'To Do', 'id': '10000', 'statusCategory': {'self': 'https://ndsingh.atlassian.net/rest/api/3/statuscategory/2', 'id': 2, 'key': 'new', 'colorName': 'blue-gray', 'name': 'To Do'}}, 'components': [], 'timeoriginalestimate': None, 'description': None, 'customfield_10010': None, 'customfield_10014': None, 'customfield_10015': None, 'timetracking': {}, 'customfield_10005': None, 'customfield_10006': None, 'customfield_10007': None, 'security': None, 'customfield_10008': None, 'customfield_10009': None, 'aggregatetimeestimate': None, 'attachment': [], 'summary': 'Nothing at the moment', 'creator': {'self': 'https://ndsingh.atlassian.net/rest/api/3/user?accountId=712020%3Ab7569eea-9d96-46ba-8f8a-7a3a84d14125', 'accountId': '712020:b7569eea-9d96-46ba-8f8a-7a3a84d14125', 'emailAddress': 'nanakdeep37@gmail.com', 'avatarUrls': {'48x48': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '24x24': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '16x16': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '32x32': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png'}, 'displayName': 'Nanakdeep Singh Sidhu', 'active': True, 'timeZone': 'Asia/Calcutta', 'accountType': 'atlassian'}, 'subtasks': [], 'reporter': {'self': 'https://ndsingh.atlassian.net/rest/api/3/user?accountId=712020%3Ab7569eea-9d96-46ba-8f8a-7a3a84d14125', 'accountId': '712020:b7569eea-9d96-46ba-8f8a-7a3a84d14125', 'emailAddress': 'nanakdeep37@gmail.com', 'avatarUrls': {'48x48': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '24x24': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '16x16': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '32x32': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png'}, 'displayName': 'Nanakdeep Singh Sidhu', 'active': True, 'timeZone': 'Asia/Calcutta', 'accountType': 'atlassian'}, 'aggregateprogress': {'progress': 0, 'total': 0}, 'customfield_10001': None, 'customfield_10002': None, 'customfield_10003': None, 'customfield_10004': None, 'environment': None, 'duedate': None, 'progress': {'progress': 0, 'total': 0}, 'comment': {'comments': [], 'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/10002/comment', 'maxResults': 0, 'total': 0, 'startAt': 0}, 'votes': {'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/KAN-3/votes', 'votes': 0, 'hasVoted': False}, 'worklog': {'startAt': 0, 'maxResults': 20, 'total': 0, 'worklogs': []}}}, {'expand': 'renderedFields,names,schema,operations,editmeta,changelog,versionedRepresentations,customfield_10010.requestTypePractice', 'id': '10001', 'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/10001', 'key': 'KAN-2', 'fields': {'statuscategorychangedate': '2024-02-01T15:47:55.731+0530', 'issuetype': {'self': 'https://ndsingh.atlassian.net/rest/api/3/issuetype/10001', 'id': '10001', 'description': 'A small, distinct piece of work.', 'iconUrl': 'https://ndsingh.atlassian.net/rest/api/2/universal_avatar/view/type/issuetype/avatar/10318?size=medium', 'name': 'Task', 'subtask': False, 'avatarId': 10318, 'entityId': '2b85f1bd-d03d-46de-93e7-02fadb099ade', 'hierarchyLevel': 0}, 'timespent': None, 'project': {'self': 'https://ndsingh.atlassian.net/rest/api/3/project/10000', 'id': '10000', 'key': 'KAN', 'name': 'My Kanban Project', 'projectTypeKey': 'software', 'simplified': True, 'avatarUrls': {'48x48': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412', '24x24': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412?size=small', '16x16': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412?size=xsmall', '32x32': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412?size=medium'}}, 'customfield_10031': None, 'customfield_10032': None, 'fixVersions': [], 'aggregatetimespent': None, 'resolution': None, 'customfield_10027': None, 'customfield_10028': None, 'customfield_10029': None, 'resolutiondate': None, 'workratio': -1, 'issuerestriction': {'issuerestrictions': {}, 'shouldDisplay': True}, 'watches': {'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/KAN-2/watchers', 'watchCount': 1, 'isWatching': True}, 'lastViewed': '2024-02-02T12:33:14.285+0530', 'created': '2024-02-01T15:47:55.458+0530', 'customfield_10020': None, 'customfield_10021': None, 'customfield_10022': None, 'priority': {'self': 'https://ndsingh.atlassian.net/rest/api/3/priority/3', 'iconUrl': 'https://ndsingh.atlassian.net/images/icons/priorities/medium.svg', 'name': 'Medium', 'id': '3'}, 'customfield_10023': None, 'customfield_10024': None, 'customfield_10025': None, 'labels': [], 'customfield_10026': None, 'customfield_10016': None, 'customfield_10017': None, 'customfield_10018': {'hasEpicLinkFieldDependency': False, 'showField': False, 'nonEditableReason': {'reason': 'PLUGIN_LICENSE_ERROR', 'message': 'The Parent Link is only available to Jira Premium users.'}}, 'customfield_10019': '0|i00007:', 'aggregatetimeoriginalestimate': None, 'timeestimate': None, 'versions': [], 'issuelinks': [], 'assignee': None, 'updated': '2024-02-02T12:12:44.581+0530', 'status': {'self': 'https://ndsingh.atlassian.net/rest/api/3/status/10000', 'description': '', 'iconUrl': 'https://ndsingh.atlassian.net/', 'name': 'To Do', 'id': '10000', 'statusCategory': {'self': 'https://ndsingh.atlassian.net/rest/api/3/statuscategory/2', 'id': 2, 'key': 'new', 'colorName': 'blue-gray', 'name': 'To Do'}}, 'components': [], 'timeoriginalestimate': None, 'description': {'version': 1, 'type': 'doc', 'content': [{'type': 'paragraph', 'content': []}, {'type': 'paragraph', 'content': [{'type': 'text', 'text': 'here'}]}]}, 'customfield_10010': None, 'customfield_10014': None, 'customfield_10015': None, 'timetracking': {}, 'customfield_10005': None, 'customfield_10006': None, 'security': None, 'customfield_10007': None, 'customfield_10008': None, 'customfield_10009': None, 'attachment': [], 'aggregatetimeestimate': None, 'summary': 'John Doe, currently lives at 1234 Elm Street, Springfield, Anywhere 12345. He can be reached at johndoe@email.com or at the phone number 555-123-4567. His social security number is 123-45-678 He now works at Acme Corp and his employee ID is 123456.', 'creator': {'self': 'https://ndsingh.atlassian.net/rest/api/3/user?accountId=712020%3Ab7569eea-9d96-46ba-8f8a-7a3a84d14125', 'accountId': '712020:b7569eea-9d96-46ba-8f8a-7a3a84d14125', 'emailAddress': 'nanakdeep37@gmail.com', 'avatarUrls': {'48x48': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '24x24': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '16x16': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '32x32': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png'}, 'displayName': 'Nanakdeep Singh Sidhu', 'active': True, 'timeZone': 'Asia/Calcutta', 'accountType': 'atlassian'}, 'subtasks': [], 'reporter': {'self': 'https://ndsingh.atlassian.net/rest/api/3/user?accountId=712020%3Ab7569eea-9d96-46ba-8f8a-7a3a84d14125', 'accountId': '712020:b7569eea-9d96-46ba-8f8a-7a3a84d14125', 'emailAddress': 'nanakdeep37@gmail.com', 'avatarUrls': {'48x48': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '24x24': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '16x16': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '32x32': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png'}, 'displayName': 'Nanakdeep Singh Sidhu', 'active': True, 'timeZone': 'Asia/Calcutta', 'accountType': 'atlassian'}, 'aggregateprogress': {'progress': 0, 'total': 0}, 'customfield_10001': None, 'customfield_10002': None, 'customfield_10003': None, 'customfield_10004': None, 'environment': None, 'duedate': None, 'progress': {'progress': 0, 'total': 0}, 'votes': {'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/KAN-2/votes', 'votes': 0, 'hasVoted': False}, 'comment': {'comments': [{'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/10001/comment/10000', 'id': '10000', 'author': {'self': 'https://ndsingh.atlassian.net/rest/api/3/user?accountId=712020%3Ab7569eea-9d96-46ba-8f8a-7a3a84d14125', 'accountId': '712020:b7569eea-9d96-46ba-8f8a-7a3a84d14125', 'emailAddress': 'nanakdeep37@gmail.com', 'avatarUrls': {'48x48': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '24x24': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '16x16': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '32x32': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png'}, 'displayName': 'Nanakdeep Singh Sidhu', 'active': True, 'timeZone': 'Asia/Calcutta', 'accountType': 'atlassian'}, 'body': {'version': 1, 'type': 'doc', 'content': [{'type': 'paragraph', 'content': [{'type': 'text', 'text': 'commemt'}]}]}, 'updateAuthor': {'self': 'https://ndsingh.atlassian.net/rest/api/3/user?accountId=712020%3Ab7569eea-9d96-46ba-8f8a-7a3a84d14125', 'accountId': '712020:b7569eea-9d96-46ba-8f8a-7a3a84d14125', 'emailAddress': 'nanakdeep37@gmail.com', 'avatarUrls': {'48x48': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '24x24': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '16x16': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '32x32': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png'}, 'displayName': 'Nanakdeep Singh Sidhu', 'active': True, 'timeZone': 'Asia/Calcutta', 'accountType': 'atlassian'}, 'created': '2024-02-02T12:12:44.581+0530', 'updated': '2024-02-02T12:12:44.581+0530', 'jsdPublic': True}], 'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/10001/comment', 'maxResults': 1, 'total': 1, 'startAt': 0}, 'worklog': {'startAt': 0, 'maxResults': 20, 'total': 0, 'worklogs': []}}}, {'expand': 'renderedFields,names,schema,operations,editmeta,changelog,versionedRepresentations,customfield_10010.requestTypePractice', 'id': '10000', 'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/10000', 'key': 'KAN-1', 'fields': {'statuscategorychangedate': '2024-02-01T15:44:31.711+0530', 'issuetype': {'self': 'https://ndsingh.atlassian.net/rest/api/3/issuetype/10001', 'id': '10001', 'description': 'A small, distinct piece of work.', 'iconUrl': 'https://ndsingh.atlassian.net/rest/api/2/universal_avatar/view/type/issuetype/avatar/10318?size=medium', 'name': 'Task', 'subtask': False, 'avatarId': 10318, 'entityId': '2b85f1bd-d03d-46de-93e7-02fadb099ade', 'hierarchyLevel': 0}, 'timespent': None, 'customfield_10031': None, 'project': {'self': 'https://ndsingh.atlassian.net/rest/api/3/project/10000', 'id': '10000', 'key': 'KAN', 'name': 'My Kanban Project', 'projectTypeKey': 'software', 'simplified': True, 'avatarUrls': {'48x48': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412', '24x24': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412?size=small', '16x16': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412?size=xsmall', '32x32': 'https://ndsingh.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/10412?size=medium'}}, 'customfield_10032': None, 'fixVersions': [], 'aggregatetimespent': None, 'resolution': None, 'customfield_10027': None, 'customfield_10028': None, 'customfield_10029': None, 'resolutiondate': None, 'workratio': -1, 'issuerestriction': {'issuerestrictions': {}, 'shouldDisplay': True}, 'watches': {'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/KAN-1/watchers', 'watchCount': 1, 'isWatching': True}, 'lastViewed': '2024-02-02T15:12:46.201+0530', 'created': '2024-02-01T15:44:31.428+0530', 'customfield_10020': None, 'customfield_10021': None, 'customfield_10022': None, 'customfield_10023': None, 'priority': {'self': 'https://ndsingh.atlassian.net/rest/api/3/priority/3', 'iconUrl': 'https://ndsingh.atlassian.net/images/icons/priorities/medium.svg', 'name': 'Medium', 'id': '3'}, 'customfield_10024': None, 'customfield_10025': None, 'customfield_10026': None, 'labels': [], 'customfield_10016': None, 'customfield_10017': None, 'customfield_10018': {'hasEpicLinkFieldDependency': False, 'showField': False, 'nonEditableReason': {'reason': 'PLUGIN_LICENSE_ERROR', 'message': 'The Parent Link is only available to Jira Premium users.'}}, 'customfield_10019': '0|hzzzzz:', 'timeestimate': None, 'aggregatetimeoriginalestimate': None, 'versions': [], 'issuelinks': [], 'assignee': None, 'updated': '2024-02-02T15:13:08.145+0530', 'status': {'self': 'https://ndsingh.atlassian.net/rest/api/3/status/10000', 'description': '', 'iconUrl': 'https://ndsingh.atlassian.net/', 'name': 'To Do', 'id': '10000', 'statusCategory': {'self': 'https://ndsingh.atlassian.net/rest/api/3/statuscategory/2', 'id': 2, 'key': 'new', 'colorName': 'blue-gray', 'name': 'To Do'}}, 'components': [], 'timeoriginalestimate': None, 'description': {'version': 1, 'type': 'doc', 'content': [{'type': 'paragraph', 'content': [{'type': 'text', 'text': 'This a description Nanak'}]}]}, 'customfield_10010': None, 'customfield_10014': None, 'customfield_10015': None, 'timetracking': {}, 'customfield_10005': None, 'customfield_10006': None, 'security': None, 'customfield_10007': None, 'customfield_10008': None, 'customfield_10009': None, 'attachment': [], 'aggregatetimeestimate': None, 'summary': 'Do a test for the user John Doe with the email johndoe@email.com', 'creator': {'self': 'https://ndsingh.atlassian.net/rest/api/3/user?accountId=712020%3Ab7569eea-9d96-46ba-8f8a-7a3a84d14125', 'accountId': '712020:b7569eea-9d96-46ba-8f8a-7a3a84d14125', 'emailAddress': 'nanakdeep37@gmail.com', 'avatarUrls': {'48x48': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '24x24': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '16x16': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '32x32': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png'}, 'displayName': 'Nanakdeep Singh Sidhu', 'active': True, 'timeZone': 'Asia/Calcutta', 'accountType': 'atlassian'}, 'subtasks': [], 'reporter': {'self': 'https://ndsingh.atlassian.net/rest/api/3/user?accountId=712020%3Ab7569eea-9d96-46ba-8f8a-7a3a84d14125', 'accountId': '712020:b7569eea-9d96-46ba-8f8a-7a3a84d14125', 'emailAddress': 'nanakdeep37@gmail.com', 'avatarUrls': {'48x48': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '24x24': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '16x16': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '32x32': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png'}, 'displayName': 'Nanakdeep Singh Sidhu', 'active': True, 'timeZone': 'Asia/Calcutta', 'accountType': 'atlassian'}, 'aggregateprogress': {'progress': 0, 'total': 0}, 'customfield_10001': None, 'customfield_10002': None, 'customfield_10003': None, 'customfield_10004': None, 'environment': None, 'duedate': None, 'progress': {'progress': 0, 'total': 0}, 'votes': {'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/KAN-1/votes', 'votes': 0, 'hasVoted': False}, 'comment': {'comments': [{'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/10000/comment/10002', 'id': '10002', 'author': {'self': 'https://ndsingh.atlassian.net/rest/api/3/user?accountId=712020%3Ab7569eea-9d96-46ba-8f8a-7a3a84d14125', 'accountId': '712020:b7569eea-9d96-46ba-8f8a-7a3a84d14125', 'emailAddress': 'nanakdeep37@gmail.com', 'avatarUrls': {'48x48': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '24x24': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '16x16': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '32x32': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png'}, 'displayName': 'Nanakdeep Singh Sidhu', 'active': True, 'timeZone': 'Asia/Calcutta', 'accountType': 'atlassian'}, 'body': {'version': 1, 'type': 'doc', 'content': [{'type': 'paragraph', 'content': [{'type': 'text', 'text': 'This is a comment Nanak'}]}]}, 'updateAuthor': {'self': 'https://ndsingh.atlassian.net/rest/api/3/user?accountId=712020%3Ab7569eea-9d96-46ba-8f8a-7a3a84d14125', 'accountId': '712020:b7569eea-9d96-46ba-8f8a-7a3a84d14125', 'emailAddress': 'nanakdeep37@gmail.com', 'avatarUrls': {'48x48': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '24x24': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '16x16': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png', '32x32': 'https://secure.gravatar.com/avatar/6885b041fa1c4222247d2928291723e2?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FNS-5.png'}, 'displayName': 'Nanakdeep Singh Sidhu', 'active': True, 'timeZone': 'Asia/Calcutta', 'accountType': 'atlassian'}, 'created': '2024-02-02T15:13:02.929+0530', 'updated': '2024-02-02T15:13:02.929+0530', 'jsdPublic': True}], 'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/10000/comment', 'maxResults': 1, 'total': 1, 'startAt': 0}, 'worklog': {'startAt': 0, 'maxResults': 20, 'total': 0, 'worklogs': []}}}]
# Out:
# [{'expand': 'renderedFields,names,schema,operations,editmeta,changelog,versionedRepresentations,customfield_10010.requestTypePractice',
#   'id': '10003',
#   'self': 'https://ndsingh.atlassian.net/rest/api/3/issue/10003',
#   'key': 'KAN-4',
#   'fields': {'statuscategorychangedate': '2024-02-01T17:10:48.311+0530',
#    'issuetype': {'self': 'https://ndsingh.atlassian.net/rest/api/3/issuetype/10001',
#     'id': '10001',
#     'description': 'A small, distinct piece of work.',
#     'iconUrl': 'https://ndsingh.atlassian.net/rest/api/2/universal_avatar/view/type/issuetype/avatar/10318?size=medium',
#     'name': 'Task',
#     'subtask': False,
#     'avatarId': 10318,
#     'entityId': '2b85f1bd-d03d-46de-93e7-02fadb099ade',
#     'hierarchyLevel': 0},
#    'timespent': None,
#    'customfield_10031': None,
#    'project': {'self': 'https://ndsingh.atlassian.net/rest/api/3/project/10000',
#     'id': '10000',
#     'key': 'KAN',
#     'name': 'My Kanban Project',
# ...

# %%
import io

filepath = "./test_doc.docx"

# Open the file in binary mode and read its content
with open(filepath, "rb") as f:
    file_content = f.read()

# Create a BytesIO object using the read content
myBytesIO = io.BytesIO(file_content)

# Seek to the beginning of the BytesIO object
# Out:
# <class '_io.BytesIO'>

# %%
from utils.constants import FileEntry
files=[myBytesIO]
documents=[]
for file in files:
        contents = file.read()
        document = FileEntry("test_doc.docx", contents)
        print(type(contents))
        documents.append(document)
print(documents)
# Out:
# <class 'bytes'>
# [FileEntry(filename='test_doc.docx', file_object=b'')]

# %%
from utils.io import FileProcessor
inst=FileProcessor(documents,0)
out=inst.process_files()
out
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 from utils.io import FileProcessor
#       2 inst=FileProcessor(documents,0)
#       3 out=inst.process_files()
#
# File ~/Projects/Code/JIRA_PII/utils/io.py:14
#      12 from utils.constants import FileEntry, FileType, PredictionTypes
#      13 from utils.encryption import calculate_sha256
# ---> 14 from utils.ocr import get_docx_text, get_excel_text, get_image_text, get_pdf_text
#      17 class FileProcessor:
#      18     def __init__(self, documents: list, request_id: str, segregate: bool = False):
#
# File ~/Projects/Code/JIRA_PII/utils/ocr.py:15
#      13 from nltk.corpus import stopwords
#      14 from nltk.stem import WordNetLemmatizer
# ---> 15 from paddleocr import PaddleOCR
#      16 from PIL import Image
#      18 # HACK
#      19 # os.environ["KMP_DUPLICATE_LIB_OK"] = "True"
#
# ...

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification , pipeline
model_path="./models/deberta_finetuned_pii"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForTokenClassification.from_pretrained(model_path)

def get_leaks(issues):

    gen = pipeline("token-classification",model=model,tokenizer=tokenizer, device=-1)
    tagged_issues=[]
    ''' look for issue["fields"]["summary"], issue["fields"]["description"]["content"]["content"]["text"] , issue["fields"]["comment"]["comments"]["body"]["content"]["content"]["text"]
    '''   
    for issue in issues:
        summary=issue["fields"]["summary"]
        # print(issue)
        PII_summary,PII_comments,PII_description=None,None,None
        description=issue["fields"].get('description')
        if description:
            description=description["content"]
            des_string=""
            for i in description:
                for j in i["content"]:
                    # print(j)
                    des_string+=j["text"]
            description=des_string
        # print("******************************************")
        if description:
            PII_description=gen(description, aggregation_strategy="first")
        comments=issue["fields"]["comment"]["comments"]
        # print(comments)
        
        issue_review={}
        PII_summary=gen(summary, aggregation_strategy="first")

        PII_comments=[]
        for comment in comments:
            # print(comment["body"])
            comment_data=comment["body"]["content"]
            comment_string=""
            for j in comment_data:
                # print(j["content"])
                for k in j["content"]:
                    # print(k)
                    comment_string+=k['text']
            PII_comment=gen(comment_string, aggregation_strategy="first")
            if PII_comment:
                PII_comments.append({"id":f"{issue['id']}/{comment['id']}",'PII_leak':True,"Leaks":PII_comment})

        if PII_summary or PII_comments or PII_description:
            issue_review['id']=issue["id"]
            issue_review['piiLeak']= True
            if PII_summary:
                issue_review["title"]=PII_summary
            if PII_description:
                issue_review["description"]=PII_description
            if PII_comments:
                issue_review["comments"]=PII_comments


        else:
            issue_review['id']=issue["id"]
            issue_review['piiLeak']= False

        tagged_issues.append(issue_review)
        
    return tagged_issues

# %%
issues=get_issues("KAN")
    # print(issues)

for i in get_leaks(issues):
    print(i)
# Out:
# /Users/nanakdeepsingh/Projects/Code/JIRA_PII/.venv/lib/python3.9/site-packages/transformers/pipelines/token_classification.py:393: UserWarning: Tokenizer does not support real words, using fallback heuristic
#   warnings.warn(
# {'id': '10003', 'piiLeak': False}
# {'id': '10002', 'piiLeak': False}
# ...
